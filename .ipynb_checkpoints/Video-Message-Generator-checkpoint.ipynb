# %% [markdown]
# # Video Message Generator from Youtube
#
# Hello, today I will explain how to create an interesting application to create video messages from Youtube Videos.

# %% [markdown]
# In SageMaker Notebook we have loaded our custom python enviroment

# %%
import sys ,os
print(sys.prefix)
# Out:
# /home/ec2-user/anaconda3/envs/VideoMessage

# %% [markdown]
# However if we want to install to our enviroment by using our terminal we have to be careful, becase Sagemaker runs on their own container,
# then in the  terminal of Sagemaker we have to load propertly the enviroment that we have created

# %%
Sagemaker = True
if Sagemaker :
    env='source activate python3 && conda activate VideoMessage &&'
else:
    env=''

# %%
# !echo -e 'import sys , os\nprint(sys.prefix)\nprint("Hello World!")\n'> hello.py

# %%
cat hello.py
# Out:
# import sys , os
# print(sys.prefix)
# print("Hello World!")

# %% [markdown]
# For example if we run the hello world without loading we get

# %%
os.system('python hello.py')
# Out:
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv
# Hello World!
# 0

# %% [markdown]
# As you see in Sagemaker the enviroment is different as we wanted

# %%
os.system('source activate python3 && python hello.py')
# Out:
# /home/ec2-user/anaconda3/envs/python3
# Hello World!
# 0

# %%
base='source activate python3 &&'

# %% [markdown]
# So we need to call with our custom enviroment

# %%
os.system('{}python hello.py'.format(env))
# Out:
# /home/ec2-user/anaconda3/envs/VideoMessage
# Hello World!
# 0

# %%
#os.system('conda activate VideoMessage && python hello.py')

# %% [markdown]
# ## Step 1. Setup of the dependencies
#
# In this part we have install all dependencies of our custom program

# %%
is_first_time = True

# %%
#Install dependency
# Download pretrained model
# Import the os module
import os
# Get the current working directory
parent_dir = os.getcwd()
print(parent_dir)
if is_first_time:
    # Directory 
    directory = "sample_data"
    # Path 
    path = os.path.join(parent_dir, directory) 
    print(path)
    try:
        os.mkdir(path)
        print("Directory '% s' created" % directory) 
    except Exception:
         print("Directory '% s'was already created" % directory)
    os.system('git clone https://github.com/Cloud-Data-Science/Wav2Lip')
    os.system('cd Wav2Lip &&{} pip install  -r requirements.txt'.format(env))
# Out:
# /home/ec2-user/SageMaker/VideoMessageGen
# /home/ec2-user/SageMaker/VideoMessageGen/sample_data
# Directory 'sample_data'was already created
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting librosa==0.7.0
#   Downloading librosa-0.7.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numpy==1.17.1
#   Downloading numpy-1.17.1-cp37-cp37m-manylinux1_x86_64.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 78.2 MB/s eta 0:00:00
# Collecting opencv-contrib-python>=4.2.0.34
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 34.8 MB/s eta 0:00:00
# Collecting opencv-python==4.1.0.25
#   Downloading opencv_python-4.1.0.25-cp37-cp37m-manylinux1_x86_64.whl (26.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 27.0 MB/s eta 0:00:00
# Collecting torch==1.1.0
#   Downloading torch-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (676.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 MB 1.2 MB/s eta 0:00:00
# Collecting torchvision==0.3.0
#   Downloading torchvision-0.3.0-cp37-cp37m-manylinux1_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 37.8 MB/s eta 0:00:00
# Collecting tqdm==4.45.0
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 16.2 MB/s eta 0:00:00
# Collecting numba==0.48
#   Downloading numba-0.48.0-1-cp37-cp37m-manylinux2014_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 25.6 MB/s eta 0:00:00
# Collecting audioread>=2.0.0
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 67.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scipy>=1.0.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 50.1 MB/s eta 0:00:00
# Collecting scikit-learn!=0.19.0,>=0.14.0
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 25.7 MB/s eta 0:00:00
# Collecting joblib>=0.12
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 49.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=3.0.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.7.0->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: six>=1.3 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.7.0->-r requirements.txt (line 1)) (1.16.0)
# Collecting resampy>=0.2.0
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.1 MB/s eta 0:00:00
# Collecting soundfile>=0.9.0
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Collecting pillow>=4.1.1
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from numba==0.48->-r requirements.txt (line 8)) (65.3.0)
# Collecting llvmlite<0.32.0,>=0.31.0dev0
#   Downloading llvmlite-0.31.0-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 30.0 MB/s eta 0:00:00
# Collecting resampy>=0.2.0
#   Downloading resampy-0.4.1-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.5 MB/s eta 0:00:00
#   Downloading resampy-0.4.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 34.0 MB/s eta 0:00:00
#   Downloading resampy-0.3.1-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0
#   Downloading cffi-1.15.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 7.7 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 33.3 MB/s eta 0:00:00
# Building wheels for collected packages: librosa, audioread
#   Building wheel for librosa (setup.py): started
#   Building wheel for librosa (setup.py): finished with status 'done'
#   Created wheel for librosa: filename=librosa-0.7.0-py3-none-any.whl size=1598348 sha256=6989a877258cef904b02e0c8709313bf8cf77af2eabd2d84fc323d5e6bcce3c9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/f5/0d/b1/71a4e1863d7577a218f771df59c7582996580fa07ac79d68fd
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23703 sha256=99712ee8935bc615c5f0ecb40b52e2b12464b21fe278874c58777146808ed641
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/71/a4/fa/24175dada88ca37d7fd22ffec10b33cb0a4909d7d07f04101f
# Successfully built librosa audioread
# Installing collected packages: llvmlite, tqdm, threadpoolctl, pycparser, pillow, numpy, joblib, audioread, torch, scipy, opencv-python, opencv-contrib-python, numba, cffi, torchvision, soundfile, scikit-learn, resampy, librosa
# Successfully installed audioread-3.0.0 cffi-1.15.1 joblib-1.1.0 librosa-0.7.0 llvmlite-0.31.0 numba-0.48.0 numpy-1.17.1 opencv-contrib-python-4.6.0.66 opencv-python-4.1.0.25 pillow-9.2.0 pycparser-2.21 resampy-0.3.1 scikit-learn-1.0.2 scipy-1.7.3 soundfile-0.10.3.post1 threadpoolctl-3.1.0 torch-1.1.0 torchvision-0.3.0 tqdm-4.45.0

# %%
from utils.default_models import ensure_default_models
from pathlib import Path

# %%
## Load the models one by one.
print("Preparing the models of Wav2Lip")
ensure_default_models(Path("Wav2Lip"))
# Out:
# Preparing the models of Wav2Lip
# Wav2Lip/checkpoints/wav2lip_gan.pth
# Wav2Lip/face_detection/detection/sfd/s3fd.pth

# %%
if is_first_time:
    os.system('git clone https://github.com/Cloud-Data-Science/Coqui-TTS -b multilingual-torchaudio-SE TTS')
    os.system('{} pip install -q -e TTS/'.format(env))
    os.system('{} pip install -q torchaudio==0.9.0'.format(env))
    os.system('{} pip install -q youtube-dl'.format(env))
    os.system('{} pip install ffmpeg-python'.format(env))
    os.system('{} pip install gradio==3.0.4'.format(env))
# Out:
# fatal: destination path 'TTS' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 48.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=3134a736adb749d819341b48543f3cf58b9c36601f9ee83c7ab6bc731c8138ba
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-0.18.2
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting gradio==3.0.4
#   Downloading gradio-3.0.4-py3-none-any.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 107.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (3.5.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (2.28.1)
# Collecting fastapi
#   Downloading fastapi-0.83.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 17.8 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 95.7 MB/s eta 0:00:00
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Jinja2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (3.1.2)
# Collecting orjson
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.2/270.2 kB 62.0 MB/s eta 0:00:00
# Collecting analytics-python
#   Downloading analytics_python-1.4.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (9.2.0)
# Collecting pycryptodome
#   Downloading pycryptodome-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 41.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (1.19.5)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting paramiko
#   Using cached paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gradio==3.0.4) (1.3.5)
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 27.3 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.18.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 18.6 MB/s eta 0:00:00
# Collecting attrs>=17.3.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 18.3 MB/s eta 0:00:00
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 39.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.3/231.3 kB 56.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 26.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from aiohttp->gradio==3.0.4) (4.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from aiohttp->gradio==3.0.4) (2.1.1)
# Requirement already satisfied: python-dateutil>2.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from analytics-python->gradio==3.0.4) (2.8.2)
# Collecting backoff==1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from analytics-python->gradio==3.0.4) (1.16.0)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests->gradio==3.0.4) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests->gradio==3.0.4) (2022.6.15.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests->gradio==3.0.4) (1.26.12)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from fastapi->gradio==3.0.4) (1.10.2)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from Jinja2->gradio==3.0.4) (2.1.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 12.0 MB/s eta 0:00:00
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->gradio==3.0.4) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->gradio==3.0.4) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->gradio==3.0.4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->gradio==3.0.4) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->gradio==3.0.4) (4.37.1)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from pandas->gradio==3.0.4) (2022.2.1)
# Collecting pynacl>=1.0.1
#   Using cached PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting cryptography>=2.5
#   Downloading cryptography-38.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 133.7 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Using cached bcrypt-4.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (594 kB)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from uvicorn->gradio==3.0.4) (8.1.3)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from click>=7.0->uvicorn->gradio==3.0.4) (4.12.0)
# Requirement already satisfied: cffi>=1.12 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from cryptography>=2.5->paramiko->gradio==3.0.4) (1.15.1)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->gradio==3.0.4) (2.21)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from importlib-metadata->click>=7.0->uvicorn->gradio==3.0.4) (3.8.1)
# Building wheels for collected packages: ffmpy, python-multipart
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4693 sha256=b974bb7a83e2976f521ce25f3bce3a3282607f204e80902d6a594793389acf33
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/13/e4/6c/e8059816e86796a597c6e6b0d4c880630f51a1fcfa0befd5e6
#   Building wheel for python-multipart (setup.py): started
#   Building wheel for python-multipart (setup.py): finished with status 'done'
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31671 sha256=5f71426785bda482b4ec57562c8bcafc3943ca6461f3161d9b6d7465fe498b49
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
# Successfully built ffmpy python-multipart
# Installing collected packages: pydub, monotonic, ffmpy, uc-micro-py, sniffio, python-multipart, pycryptodome, orjson, multidict, mdurl, h11, frozenlist, bcrypt, backoff, attrs, asynctest, async-timeout, yarl, pynacl, markdown-it-py, linkify-it-py, cryptography, anyio, analytics-python, aiosignal, uvicorn, starlette, paramiko, mdit-py-plugins, aiohttp, fastapi, gradio
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 analytics-python-1.4.0 anyio-3.6.1 async-timeout-4.0.2 asynctest-0.13.0 attrs-22.1.0 backoff-1.10.0 bcrypt-4.0.0 cryptography-38.0.1 fastapi-0.83.0 ffmpy-0.3.0 frozenlist-1.3.1 gradio-3.0.4 h11-0.13.0 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.0 mdurl-0.1.2 monotonic-1.6 multidict-6.0.2 orjson-3.8.0 paramiko-2.11.0 pycryptodome-3.15.0 pydub-0.25.1 pynacl-1.5.0 python-multipart-0.0.5 sniffio-1.3.0 starlette-0.19.1 uc-micro-py-1.0.1 uvicorn-0.18.3 yarl-1.8.1

# %%
if is_first_time:
    os.system('{} pip install pytube==12.1.0'.format(env))
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting pytube==12.1.0
#   Downloading pytube-12.1.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-12.1.0

# %%
#this code for recording audio
from IPython.display import HTML, Audio
#from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg
from pytube import YouTube
import random

# %%
from IPython.display import HTML
from base64 import b64encode
def showVideo(path):
  mp4 = open(str(path),'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width=700 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url)

from IPython.display import clear_output

# %%
from subprocess import call
import os

# %%
from datetime import datetime
def time_between(t1, t2):
    FMT = '%H:%M:%S'
    t1 = datetime.strptime(t1, FMT)
    t2 = datetime.strptime(t2, FMT)
    delta = t2 - t1
    return str(delta)

# %%
time_between("00:00:01","00:00:10" )
# Out:
# '0:00:09'

# %%
def download_video(url):

    print("Downloading...")
    local_file = (
        YouTube(url)
        .streams.filter(progressive=True, file_extension="mp4")
        .first()
        .download(filename="youtube{}.mp4".format(random.randint(0, 10000)))
    )
    print("Downloaded")
    return local_file
  # download(output_path=destination, filename="name.mp4")

# %%
def download_youtube(url):
    #Select a Youtube Video
    #find youtube video id
    from urllib import parse as urlparse
    url_data = urlparse.urlparse(url)
    query = urlparse.parse_qs(url_data.query)
    YOUTUBE_ID = query["v"][0]
    url_download ="https://www.youtube.com/watch?v={}".format(YOUTUBE_ID)
    # download the youtube with the given ID
    #call(["youtube-dl", "-f","bestvideo[ext=mp4]","--output","youtube.%(ext)s",url_download])
    #call(["youtube-dl", "-f","mp4","--output","youtube.%(ext)s",url_download])
    os.system("{} youtube-dl -f  mp4 --output youtube.mp4 '{}'".format(env,url_download))
    #!youtube-dl -f 'bestvideo[ext=mp4]' --output "youtube.%(ext)s" https://www.youtube.com/watch?v=$YOUTUBE_ID

# %%
if is_first_time:
    URL = 'https://www.youtube.com/watch?v=xw5dvItD5zY'
    #URL = 'https://www.youtube.com/watch?v=uIaY0l5qV0c'
    #download_youtube(URL)
    download_video(URL)
# Out:
# Downloading...
# Downloaded

# %%
def cleanup():
    import pathlib
    import glob
    types = ('*.mp4','*.mp3', '*.wav') # the tuple of file types
    #Finding mp4 and wave files
    junks = []
    for files in types:
        junks.extend(glob.glob(files))
    try:    
        # Deleting those files
        for junk in junks:
            print("Deleting",junk)
            # Setting the path for the file to delete
            file = pathlib.Path(junk)
            # Calling the unlink method on the path
            file.unlink()               
    except Exception:
        print("I cannot delete the file because it is being used by another process")

# %%
def clean_data():
    # importing all necessary libraries
    import sys, os
    # initial directory
    home_dir = os.getcwd()
    # some non existing directory
    fd = 'sample_data/'
    # Join various path components
    path_to_clean=os.path.join(home_dir,fd)
    print("Path to clean:",path_to_clean)
    # trying to insert to false directory
    try:
        os.chdir(path_to_clean)
        print("Inside to clean", os.getcwd())
        cleanup()
    # Caching the exception
    except:
        print("Something wrong with specified\
        directory. Exception- ", sys.exc_info())
    # handling with finally
    finally:
        print("Restoring the path")
        os.chdir(home_dir)
        print("Current directory is-", os.getcwd())

# %%
def youtube_trim(url,start,end):
    #cancel previous youtube
    cleanup()
    #download youtube
    #download_youtube(url) # with youtube-dl (slow)
    input_videos=download_video(url)
    # Get the current working directory
    parent_dir = os.getcwd()
    # Trim the video (start, end) seconds
    start =  start
    end =  end
    #Note: the trimmed video must have face on all frames
    #interval = end - start
    interval = time_between(start, end)
    #trimmed_video= parent_dir+'/sample_data/input_vid{}.mp4'.format(random.randint(0, 10000))
    #trimmed_audio= parent_dir+'/sample_data/input_audio{}.mp3'.format(random.randint(0, 10000))
    trimmed_video= parent_dir+'/sample_data/input_video.mp4'
    trimmed_audio= parent_dir+'/sample_data/input_audio.mp3'
    #delete trimmed if already exits
    clean_data()
    #call(["rm","-f",trimmed_audio])
    #call(["rm","-f",trimmed_video])
    
    #!rm -f {trimmed_video}
    # cut the video  
    call(["ffmpeg","-y","-i",input_videos,"-ss", start,"-t",interval,"-async","1",trimmed_video])
    #!ffmpeg -y -i youtube.mp4 -ss {start} -t {interval} -async 1 {trimmed_video}
    # cut the audio
    call(["ffmpeg","-i",trimmed_video, "-q:a", "0", "-map","a",trimmed_audio])
    #Preview trimmed video
    #clear_output()
    print("Trimmed Video+Audio")
    return trimmed_video, trimmed_audio

# %%
#URL = 'https://www.youtube.com/watch?v=uIaY0l5qV0c'
#Text=' I am clonning your voice. Charles!. Machine intelligence is the last invention that humanity will ever need to make.'
#trimmed_video, trimmed_audio=youtube_trim(URL, "00:00:29",  "00:01:05")
#showVideo(trimmed_video)

# %%
#trimmed_video, trimmed_audio=youtube_trim(URL,"00:00:01","00:00:10")
#showVideo(trimmed_video)

# %%
if is_first_time:
    os.system('git clone https://github.com/Cloud-Data-Science/Voice-Cloning VOICE')
    os.system('cd VOICE &&{} pip install  -r requirements.txt'.format(env))
    os.system('mv ./VOICE/*.tar .')
    os.system('mv ./VOICE/*.json .')
    os.system('rm -r VOICE -f')
# Out:
# Cloning into 'VOICE'...
# Downloading SE_checkpoint.pth.tar (45 MB)
# Error downloading object: SE_checkpoint.pth.tar (8f96efb): Smudge error: Error downloading SE_checkpoint.pth.tar (8f96efb20cbeeefd81fd8336d7f0155bf8902f82f9474e58ccb19d9e12345172): batch response: This repository is over its data quota. Account responsible for LFS bandwidth should purchase more data packs to restore access.
#
# Errors logged to '/home/ec2-user/SageMaker/VideoMessageGen/VOICE/.git/lfs/logs/20220913T221808.043008622.log'.
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: SE_checkpoint.pth.tar: smudge filter lfs failed
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: TTS in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: torchaudio==0.9.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: torch==1.9.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from torchaudio==0.9.0->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from torch==1.9.0->torchaudio==0.9.0->-r requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: coqpit in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.0.16)
# Requirement already satisfied: cython in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.29.32)
# Requirement already satisfied: pypinyin in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.47.1)
# Requirement already satisfied: librosa==0.8.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: inflect in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: unidic-lite==1.0.8 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.0.8)
# Requirement already satisfied: tensorboardX in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (2.5.1)
# Requirement already satisfied: mecab-python3==1.0.3 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.0.3)
# Requirement already satisfied: fsspec>=2021.04.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (2022.8.2)
# Requirement already satisfied: gdown in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (4.5.1)
# Requirement already satisfied: jieba in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.42.1)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (3.5.3)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (4.45.0)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.2.3)
# Requirement already satisfied: numpy==1.19.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: pysbd in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: numba==0.53 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.53.0)
# Requirement already satisfied: umap-learn==0.5.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: soundfile in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.10.3.post1)
# Requirement already satisfied: anyascii in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: flask in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from TTS->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: decorator>=3.0.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: pooch>=1.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: audioread>=2.0.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from librosa==0.8.0->TTS->-r requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from numba==0.53->TTS->-r requirements.txt (line 1)) (0.36.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from numba==0.53->TTS->-r requirements.txt (line 1)) (65.3.0)
# Requirement already satisfied: pynndescent>=0.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from umap-learn==0.5.1->TTS->-r requirements.txt (line 1)) (0.5.7)
# Requirement already satisfied: Babel~=2.8.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: num2words==0.5.10 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (0.5.10)
# Requirement already satisfied: gruut-ipa~=0.9.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (0.9.3)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (0.9.8)
# Requirement already satisfied: gruut-lang-fr~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: gruut-lang-cs~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-nl~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-sv~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-es~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-de~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-pt~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-ru~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: gruut-lang-it~=1.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (1.2)
# Requirement already satisfied: docopt>=0.6.2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from num2words==0.5.10->gruut[cs,de,es,fr,it,nl,pt,ru,sv]~=1.2.0->TTS->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from soundfile->TTS->-r requirements.txt (line 1)) (1.15.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from flask->TTS->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from flask->TTS->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: itsdangerous>=2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from flask->TTS->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from flask->TTS->-r requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from flask->TTS->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gdown->TTS->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gdown->TTS->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: requests[socks] in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gdown->TTS->-r requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from gdown->TTS->-r requirements.txt (line 1)) (4.11.1)
# Requirement already satisfied: pydantic in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from inflect->TTS->-r requirements.txt (line 1)) (1.10.2)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from matplotlib->TTS->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from pandas->TTS->-r requirements.txt (line 1)) (2022.2.1)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from tensorboardX->TTS->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from cffi>=1.0->soundfile->TTS->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->flask->TTS->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from Jinja2>=3.0->flask->TTS->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from pooch>=1.0->librosa==0.8.0->TTS->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0->TTS->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from beautifulsoup4->gdown->TTS->-r requirements.txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests[socks]->gdown->TTS->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests[socks]->gdown->TTS->-r requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests[socks]->gdown->TTS->-r requirements.txt (line 1)) (2022.6.15.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests[socks]->gdown->TTS->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from requests[socks]->gdown->TTS->-r requirements.txt (line 1)) (1.7.1)

# %% [markdown]
# ## We verify the pandas and numpy versions

# %%
print("In our enviroment")
os.system('{} pip show pandas numpy'.format(env))
# Out:
# In our enviroment
# Name: pandas
# Version: 1.3.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: gradio, TTS
# ---
# Name: numpy
# Version: 1.19.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages
# Requires:
# Required-by: gradio, librosa, matplotlib, numba, opencv-contrib-python, opencv-python, pandas, resampy, scikit-learn, scipy, tensorboardX, torchvision, TTS, umap-learn
# 0

# %%
print("In the base enviroment")
os.system('{} pip show pandas numpy'.format(base))
# Out:
# In the base enviroment
# Name: pandas
# Version: 1.3.4
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: autovizwidget, hdijupyterutils, sagemaker, seaborn, shap, smclarify, sparkmagic, statsmodels
# ---
# Name: numpy
# Version: 1.20.3
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages
# Requires:
# Required-by: astropy, bkcharts, bokeh, Bottleneck, daal4py, h5py, hdijupyterutils, imagecodecs, imageio, matplotlib, mkl-fft, mkl-random, numba, numexpr, opencv-python, pandas, patsy, pyarrow, pyerfa, PyWavelets, sagemaker, sagemaker-pyspark, scikit-image, scikit-learn, scipy, seaborn, shap, smclarify, smdebug, sparkmagic, statsmodels, tables, tifffile
# 0

# %%
print("In the Jupyter enviroment")
os.system('pip show pandas numpy')
# Out:
# In the Jupyter enviroment
# Name: pandas
# Version: 1.3.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.7/site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: autovizwidget, hdijupyterutils, sagemaker, sparkmagic
# ---
# Name: numpy
# Version: 1.21.6
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.7/site-packages
# Requires:
# Required-by: Bottleneck, hdijupyterutils, numexpr, pandas, sagemaker, sagemaker-pyspark, sparkmagic
# 0

# %%
import numpy
numpy.version.version
# Out:
# '1.19.5'

# %%
if is_first_time:
    os.system('{} pip install opencv-contrib-python-headless==4.1.2.30'.format(env))
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting opencv-contrib-python-headless==4.1.2.30
#   Downloading opencv_contrib_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (27.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages (from opencv-contrib-python-headless==4.1.2.30) (1.19.5)
# Installing collected packages: opencv-contrib-python-headless
# Successfully installed opencv-contrib-python-headless-4.1.2.30

# %%
#pip install numpy==1.19.5 --upgrade --ignore-installed

# %%
import sys
VOICE_PATH = "utils/"
# add libraries into environment
sys.path.append(VOICE_PATH) # set this if VOICE is not installed globally

# %%
from utils.voice import *
# Out:
# /home/ec2-user/SageMaker/VideoMessageGen
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:False
#  | > do_amp_to_db_mel:True
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Using model: vits
#  > Speaker manager is loaded with 6 speakers: female-en-5, female-en-5
# , female-pt-4
# , male-en-2, male-en-2
# , male-pt-3
#
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400

# %%
def create_video(Text,Voicetoclone):
    out_audio=greet(Text,Voicetoclone)
    current_dir=os.getcwd()
    clonned_audio = os.path.join(current_dir, out_audio)
    
    #Start Crunching and Preview Output
    #Note: Only change these, if you have to
    pad_top =  0#@param {type:"integer"}
    pad_bottom =  10#@param {type:"integer"}
    pad_left =  0#@param {type:"integer"}
    pad_right =  0#@param {type:"integer"}
    rescaleFactor =  1#@param {type:"integer"}
    nosmooth = False #@param {type:"boolean"}
    
    out_name ="result_voice_{}.mp4".format(random.randint(0, 10000))
    out_file="../"+out_name
    
    if nosmooth == False:
        os.system('{} cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/input_video.mp4" --audio "../out/clonned_audio.wav" --outfile {} --pads {} {} {} {} --resize_factor {}'.format(env,out_file,pad_top ,pad_bottom ,pad_left ,pad_right ,rescaleFactor))
    else:
        os.system('{} cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/input_video.mp4" --audio "../out/clonned_audio.wav" --outfile {} --pads {} {} {} {} --resize_factor {} --nosmooth'.format(env,out_file,pad_top ,pad_bottom ,pad_left ,pad_right ,rescaleFactor))

    #clear_output()
    print("Creation of Video done")
    return out_name

# %%
URL = 'https://www.youtube.com/watch?v=xw5dvItD5zY'
#Testing first time
trimmed_video, trimmed_audio=youtube_trim(URL,"00:00:01","00:00:10")
showVideo(trimmed_video)
# Out:
# Deleting youtube4886.mp4
# Deleting youtube5005.mp4
# Deleting result_voice_5870.mp4
# Deleting errormessage.wav
# Downloading...
# Downloaded
# Path to clean: /home/ec2-user/SageMaker/VideoMessageGen/sample_data/
# Inside to clean /home/ec2-user/SageMaker/VideoMessageGen/sample_data
# Deleting input_video.mp4
# Deleting input_audio.mp3
# Restoring the path
# Current directory is- /home/ec2-user/SageMaker/VideoMessageGen
# ffmpeg version 5.1.1-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ec2-user/SageMaker/VideoMessageGen/youtube5422.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Google
#   Duration: 00:00:47.07, start: 0.000000, bitrate: 232 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 133 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# -async is forwarded to lavfi similarly to -af aresample=async=1:min_hard_comp=0.100000:first_pts=0.
# [libx264 @ 0x74adbc0] using SAR=1/1
# [libx264 @ 0x74adbc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x74adbc0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x74adbc0] 264 - core 164 r3098 7628a56 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ec2-user/SageMaker/VideoMessageGen/sample_data/input_video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf59.27.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 aac
# frame=  225 fps=0.0 q=-1.0 Lsize=     266kB time=00:00:09.00 bitrate= 242.2kbits/s speed=12.8x
# video:117kB audio:141kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.435906%
# [libx264 @ 0x74adbc0] frame I:1     Avg QP:17.14  size: 16594
# [libx264 @ 0x74adbc0] frame P:57    Avg QP:21.03  size:  1243
# [libx264 @ 0x74adbc0] frame B:167   Avg QP:28.93  size:   189
# [libx264 @ 0x74adbc0] consecutive B-frames:  0.4%  1.8%  0.0% 97.8%
# [libx264 @ 0x74adbc0] mb I  I16..4: 15.5% 35.1% 49.3%
# [libx264 @ 0x74adbc0] mb P  I16..4:  0.4%  0.5%  0.4%  P16..4: 15.3%  5.3%  3.4%  0.0%  0.0%    skip:74.7%
# [libx264 @ 0x74adbc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 13.6%  0.6%  0.1%  direct: 0.1%  skip:85.7%  L0:43.7% L1:53.9% BI: 2.4%
# [libx264 @ 0x74adbc0] 8x8 transform intra:37.4% inter:66.9%
# [libx264 @ 0x74adbc0] coded y,uvDC,uvAC intra: 71.9% 62.7% 37.4% inter: 1.7% 1.4% 0.0%
# [libx264 @ 0x74adbc0] i16 v,h,dc,p: 50% 19% 17% 15%
# [libx264 @ 0x74adbc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 16% 14%  4%  4%  6%  4%  6%  5%
# [libx264 @ 0x74adbc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 20% 11%  3%  4%  6%  4%  4%  3%
# [libx264 @ 0x74adbc0] i8c dc,h,v,p: 45% 14% 30% 11%
# [libx264 @ 0x74adbc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x74adbc0] ref P L0: 66.4% 10.9% 16.2%  6.5%
# [libx264 @ 0x74adbc0] ref B L0: 88.2% 10.1%  1.7%
# [libx264 @ 0x74adbc0] ref B L1: 95.9%  4.1%
# [libx264 @ 0x74adbc0] kb/s:105.77
# [aac @ 0x74adf80] Qavg: 1117.858
# Trimmed Video+Audio
# ffmpeg version 5.1.1-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/ec2-user/SageMaker/VideoMessageGen/sample_data/input_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:09.00, start: 0.000000, bitrate: 242 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 106 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/home/ec2-user/SageMaker/VideoMessageGen/sample_data/input_audio.mp3':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     TSSE            : Lavf59.27.100
#   Stream #0:0(eng): Audio: mp3, 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libmp3lame
# size=     165kB time=00:00:09.01 bitrate= 150.2kbits/s speed=70.4x
# video:0kB audio:165kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.210846%
#   <video width=700 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
Text=' I am clonning your voice. Charles!. Machine intelligence is the last invention that humanity will ever need to make.'
Voicetoclone=trimmed_audio
print(Voicetoclone)
#Testing first time
outvideo=create_video(Text,Voicetoclone)
#Preview output video
print("Final Video Preview")
final_video= parent_dir+'/'+outvideo
print("Dowload this video from", final_video)
showVideo(final_video)
# Out:
# /home/ec2-user/SageMaker/VideoMessageGen/sample_data/input_audio.mp3
# path url
# /home/ec2-user/SageMaker/VideoMessageGen/sample_data/input_audio.mp3
# usage: ffmpeg-normalize [-h] [-o OUTPUT [OUTPUT ...]] [-of OUTPUT_FOLDER] [-f]
#                         [-d] [-v] [-q] [-n] [-pr] [--version]
#                         [-nt {ebu,rms,peak}] [-t TARGET_LEVEL] [-p]
#                         [-lrt LOUDNESS_RANGE_TARGET]
#                         [--keep-loudness-range-target] [-tp TRUE_PEAK]
#                         [--offset OFFSET] [--dual-mono] [--dynamic]
#                         [-c:a AUDIO_CODEC] [-b:a AUDIO_BITRATE]
#                         [-ar SAMPLE_RATE] [-koa] [-prf PRE_FILTER]
#                         [-pof POST_FILTER] [-vn] [-c:v VIDEO_CODEC] [-sn]
#                         [-mn] [-cn] [-ei EXTRA_INPUT_OPTIONS]
#                         [-e EXTRA_OUTPUT_OPTIONS] [-ofmt OUTPUT_FORMAT]
#                         [-ext EXTENSION]
#                         input [input ...]
# ffmpeg-normalize: error: argument -o/--output: expected at least one argument
# /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  > text:  I am clonning your voice. Charles!. Machine intelligence is the last invention that humanity will ever need to make.
# Generated Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#  > Saving output to out/clonned_audio.wav
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
#   8%|▊         | 1/12 [00:02<00:30,  2.75s/it]
#  17%|█▋        | 2/12 [00:03<00:21,  2.16s/it]
#  25%|██▌       | 3/12 [00:04<00:15,  1.75s/it]
#  33%|███▎      | 4/12 [00:05<00:11,  1.46s/it]
#  42%|████▏     | 5/12 [00:05<00:08,  1.26s/it]
#  50%|█████     | 6/12 [00:06<00:06,  1.12s/it]
#  58%|█████▊    | 7/12 [00:07<00:05,  1.02s/it]
#  67%|██████▋   | 8/12 [00:08<00:03,  1.05it/s]
#  75%|███████▌  | 9/12 [00:09<00:02,  1.11it/s]
#  83%|████████▎ | 10/12 [00:09<00:01,  1.15it/s]
#  92%|█████████▏| 11/12 [00:10<00:00,  1.18it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.07it/s]
# 100%|██████████| 2/2 [01:53<00:00, 56.61s/it]ffmpeg version 5.1.1-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gmp --enable-libgme --enable-gray --enable-libaom --enable-libfribidi --enable-libass --enable-libvmaf --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librubberband --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libvorbis --enable-libopus --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libdav1d --enable-libxvid --enable-libzvbi --enable-libzimg
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '../out/clonned_audio.wav':
#   Duration: 00:00:07.30, bitrate: 256 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
# Input #1, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf58.35.100
#   Duration: 00:00:07.16, start: 0.000000, bitrate: 428 kb/s
#   Stream #1:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 419 kb/s, 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #1:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x70fc7c0] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x70fc7c0] using SAR=1/1
# [libx264 @ 0x70fc7c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x70fc7c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x70fc7c0] 264 - core 164 r3098 7628a56 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../result_voice_2632.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 16000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc59.37.100 aac
# frame=  179 fps=0.0 q=-1.0 Lsize=     210kB time=00:00:07.29 bitrate= 236.1kbits/s speed=19.7x
# video:142kB audio:63kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.731883%
# [libx264 @ 0x70fc7c0] frame I:1     Avg QP:18.17  size: 12004
# [libx264 @ 0x70fc7c0] frame P:89    Avg QP:21.61  size:  1242
# [libx264 @ 0x70fc7c0] frame B:89    Avg QP:27.36  size:   248
# [libx264 @ 0x70fc7c0] consecutive B-frames: 28.5% 14.5%  3.4% 53.6%
# [libx264 @ 0x70fc7c0] mb I  I16..4: 14.5% 82.3%  3.3%
# [libx264 @ 0x70fc7c0] mb P  I16..4:  0.3%  2.1%  0.1%  P16..4: 16.8%  5.5%  2.9%  0.0%  0.0%    skip:72.3%
# [libx264 @ 0x70fc7c0] mb B  I16..4:  0.1%  0.4%  0.0%  B16..8: 18.2%  0.5%  0.0%  direct: 0.1%  skip:80.7%  L0:50.0% L1:47.7% BI: 2.4%
# [libx264 @ 0x70fc7c0] 8x8 transform intra:83.1% inter:81.1%
# [libx264 @ 0x70fc7c0] coded y,uvDC,uvAC intra: 58.4% 50.5% 12.3% inter: 3.6% 4.1% 0.1%
# [libx264 @ 0x70fc7c0] i16 v,h,dc,p: 49% 26% 17%  8%
# [libx264 @ 0x70fc7c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 18% 32%  2%  1%  2%  1%  2%  2%
# [libx264 @ 0x70fc7c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 56% 18% 11%  2%  2%  4%  3%  2%  2%
# [libx264 @ 0x70fc7c0] i8c dc,h,v,p: 47% 18% 30%  5%
# [libx264 @ 0x70fc7c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x70fc7c0] ref P L0: 71.1% 11.1% 12.8%  5.0%
# [libx264 @ 0x70fc7c0] ref B L0: 83.7% 13.0%  3.2%
# [libx264 @ 0x70fc7c0] ref B L1: 96.0%  4.0%
# [libx264 @ 0x70fc7c0] kb/s:161.62
# [aac @ 0x70fd980] Qavg: 34432.594
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 225
# (80, 584)
# Length of mel chunks: 179
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Model loaded
# Creation of Video done
# Final Video Preview
# Dowload this video from /home/ec2-user/SageMaker/VideoMessageGen/result_voice_2632.mp4
#   <video width=700 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %%
parent_dir
# Out:
# '/home/ec2-user/SageMaker/VideoMessageGen'

# %%
def time_format_check(input1):
    timeformat = "%H:%M:%S"
    #input1 = input("At what time did sensor 1 actuate? ")
    try:
        validtime = datetime.strptime(input1, timeformat)
        print("The time format is valid", input1)
        #Do your logic with validtime, which is a valid format
        return False
    except ValueError:
        print("The time {}  has not valid format hh:mm:ss".format(input1))
        return True

# %%
def to_seconds(datetime_obj):
    from datetime import datetime
    time =datetime_obj
    date_time = datetime.strptime(time, "%H:%M:%S")
    a_timedelta = date_time - datetime(1900, 1, 1)
    seconds = a_timedelta.total_seconds()
    return seconds

# %%
def validate_youtube(url):
    #This creates a youtube objet
    try:
        yt = YouTube(url)  
    except Exception:
        print("Hi there URL seems invalid")
        return True, 0
    #This will return the length of the video in sec as an int
    video_length = yt.length
    if    video_length > 600:
        print("Your video is larger than 10 minutes")
        return True, video_length
    else:
        print("Your video is less than 10 minutes")
        return False, video_length

# %%
deltas=time_between("00:06:00","00:07:00" )
len(str(deltas))
# Out:
# 7

# %%
def video_generator(text_to_say,url,initial_time,final_time):
    print('Checking the url',url)
    check1, video_length = validate_youtube(url)
    if check1 is True: return "./demo/tryagain2.mp4"
    check2 = validate_time(initial_time,final_time, video_length)
    if check2 is True: return "./demo/tryagain0.mp4"
    trimmed_video, trimmed_audio=youtube_trim(url,initial_time,final_time)
    voicetoclone=trimmed_audio
    print(voicetoclone)
    outvideo=create_video(text_to_say,voicetoclone)
    #Preview output video
    print("Final Video Preview")
    final_video= parent_dir+'/'+outvideo
    print("DONE")
    #showVideo(final_video)
    return final_video

# %%
def validate_time(initial_time,final_time,video_length):
    is_wrong1=time_format_check(initial_time)
    is_wrong2=time_format_check(final_time) 
    #print(is_wrong1,is_wrong2)
    if is_wrong1 is False and is_wrong2 is False:
        delta=time_between(initial_time,final_time)
        if len(str(delta)) > 8:
            print("Final Time is Smaller than Initial Time: t1>t2")
            is_wrong = True
            return is_wrong
        else:
            print("OK")
            is_wrong=False
            if int(to_seconds(delta)) > 300 :
                print("The trim is larger than 5 minutes")
                is_wrong = True
                return is_wrong
            
            elif int(to_seconds(delta)) > video_length :
                print("The trim is larger than video lenght")
                is_wrong = True
                return is_wrong             
            else:
                return  is_wrong
            
    else:
        print("Your time format is invalid")
        is_wrong = True
        return is_wrong

# %%
validate_time("00:00:01","00:05:00", 200)
# Out:
# The time format is valid 00:00:01
# The time format is valid 00:05:00
# OK
# The trim is larger than video lenght
# True

# %% [markdown]
# ## Unit tests

# %%
URL = 'https://www.youtube.com/watch?v=xw5dvItD5zY'
Text=' I am clonning your voice. Charles!. Machine intelligence is the last invention that humanity will ever need to make.'
# No issue
#video_generator(Text,URL,"00:00:01","00:00:10")

# %%
validate_youtube(URL)
# Out:
# Your video is less than 10 minutes
# (False, 47)

# %%
# No issue
#video_generator(Text,URL,"00:00:01","00:00:10")

# %%
# Initial time > Final time
video_generator(Text, URL,"00:00:10","00:00:01")
# Out:
# Checking the url https://www.youtube.com/watch?v=xw5dvItD5zY
# Your video is less than 10 minutes
# The time format is valid 00:00:10
# The time format is valid 00:00:01
# Final Time is Smaller than Initial Time: t1>t2
# './demo/tryagain0.mp4'

# %%
#Trim is larger than video
video_generator(Text, URL,"00:00:01","00:05:00")
# Out:
# Checking the url https://www.youtube.com/watch?v=xw5dvItD5zY
# Your video is less than 10 minutes
# The time format is valid 00:00:01
# The time format is valid 00:05:00
# OK
# The trim is larger than video lenght
# './demo/tryagain0.mp4'

# %%
#Trim is larger than limit of 4 min
video_generator(Text, URL,"00:00:01","00:06:00")
# Out:
# Checking the url https://www.youtube.com/watch?v=xw5dvItD5zY
# Your video is less than 10 minutes
# The time format is valid 00:00:01
# The time format is valid 00:06:00
# OK
# The trim is larger than 5 minutes
# './demo/tryagain0.mp4'

# %% [markdown]
# # Web Appp Code

# %%
text_to_say=gr.inputs.Textbox(label='What would you like the voice to say? (max. 2000 characters per request)')
url =gr.inputs.Textbox(label = "Enter the YouTube URL below:")
initial_time = gr.inputs.Textbox(label='Initial time of trim? (format: hh:mm:ss)')
final_time= gr.inputs.Textbox(label='Final time to trim? (format: hh:mm:ss)')
demo = gr.Interface(fn = video_generator,
            inputs = [text_to_say,url,initial_time,final_time],
            outputs = 'video', 
            verbose = True,
            title = 'Video Speech Generator from Youtube Videos',
            description = 'A simple application that replaces the original speech of the video by your text. Wait one minute to process.',
            article = 
                        '''<div>
                            <p style="text-align: center"> 
                            All you need to do is to paste the Youtube link and 
                            set the initial time and final time of the real speach.
                            (The limit of the trim is 5 minutes and not larger than video length)
                            hit submit, then wait for compiling.
                            After that click on Play/Pause for listing to the video. 
                            The video is saved in an mp4 format.
                             For more information visit <a href="https://ruslanmv.com/">ruslanmv.com</a>
                            </p>
                        </div>''',

           examples = [['I am clonning your voice, Charles!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=xw5dvItD5zY", 
                        "00:00:01","00:00:10"],
                        ['I am clonning your voice, Jim Carrey!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=uIaY0l5qV0c",
                        "00:00:29",  "00:01:05"],
                        ['I am clonning your voice, Mark Zuckerberg!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=AYjDIFrY9rc",
                        "00:00:11", "00:00:44"],
                        ['I am clonning your voice, Ronald Reagan!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=iuoRDY9c5SQ",
                        "00:01:03",  "00:01:22"], 
                        ['I am clonning your voice, Elon Musk!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=IZ8JQ_1gytg",
                        "00:00:10",  "00:00:43"],
                        ['I am clonning your voice, Hitler!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=F08wrLyH5cs",
                        "00:00:15",  "00:00:40"],
                         ['I am clonning your voice, Alexandria!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=Eht6oIkzkew",
                        "00:00:02",  "00:00:30"], 
                         ['I am clonning your voice, Deborah!. Machine intelligence is the last invention that humanity will ever need to make.',
                        "https://www.youtube.com/watch?v=qbq4_Swj0Gg",
                        "00:00:03",  "00:0:44"],
                        ]           
            )
# Out:
# /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /home/ec2-user/anaconda3/envs/VideoMessage/lib/python3.7/site-packages/gradio/deprecation.py:40: UserWarning: `verbose` parameter is deprecated, and it has no effect
#   warnings.warn(value)

# %%
#demo.close()
#demo.launch(share=True)

# %%
#demo.close()

# %%
# No issues tests
is_first_time =False

# %%
if is_first_time:
    URL = "https://www.youtube.com/watch?v=iuoRDY9c5SQ"
    Text=' I am clonning your voice. Charles!. Machine intelligence is the last invention that humanity will ever need to make.'
    video_generator(Text,URL,  "00:01:04",  "00:01:21")
    #Preview output video
    print("Final Video Preview")
    final_video= parent_dir+'/Wav2Lip/results/result_voice.mp4'
    print("Dowload this video from", final_video)
    showVideo(final_video)

# %%
clean_data()
cleanup()
# Out:
# Path to clean: /home/ec2-user/SageMaker/VideoMessageGen/sample_data/
# Inside to clean /home/ec2-user/SageMaker/VideoMessageGen/sample_data
# Deleting input_video.mp4
# Deleting input_audio.mp3
# Restoring the path
# Current directory is- /home/ec2-user/SageMaker/VideoMessageGen
# Deleting youtube5422.mp4
# Deleting result_voice_2632.mp4
